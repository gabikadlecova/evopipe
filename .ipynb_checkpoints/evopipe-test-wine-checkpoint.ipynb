# %%
import evopipe
import warnings

from sklearn.model_selection import train_test_split
from sklearn import datasets

from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer, Binarizer
from sklearn.decomposition import PCA, KernelPCA, NMF
from sklearn.feature_selection import SelectKBest, chi2

from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

import matplotlib.pyplot as plt
import seaborn as sns

preproc_l = [MinMaxScaler(), StandardScaler(), Normalizer(), Binarizer(), PCA(), KernelPCA(), NMF(), SelectKBest(chi2)]
classif_l = [SVC(), LinearSVC(), KNeighborsClassifier(), DecisionTreeClassifier(), RandomForestClassifier(),
             AdaBoostClassifier(), QuadraticDiscriminantAnalysis()]

# %%
wine = datasets.load_wine()
train_X, test_X, train_Y, test_Y = train_test_split(wine.data, wine.target, test_size = 0.25, random_state = 0)

# %%
print("Format:")
print("------------")
print("Classifier")
print("score")
print("cross-validation score")
print("------------")
print()

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    for classif in classif_l:
        print(classif.__class__.__name__)
        classif.fit(train_X, train_Y)
        print(classif.score(test_X, test_Y))
        print(cross_val_score(classif, test_X, test_Y).mean())
        print()
# Out:
# Format:
# ------------
# Classifier
# score
# cross-validation score
# ------------
#
# SVC
# 0.5111111111111111
# 0.4680555555555556
#
# LinearSVC
# 0.8444444444444444
# 0.5555555555555555
#
# KNeighborsClassifier
# 0.7333333333333333
# 0.8009920634920635
#
# DecisionTreeClassifier
# 0.8444444444444444
# 0.8456349206349207
#
# RandomForestClassifier
# 0.9555555555555556
# 0.8916666666666666
#
# AdaBoostClassifier
# 0.8666666666666667
# 0.9109126984126984
#
# QuadraticDiscriminantAnalysis
# 1.0
# 0.4680555555555556

# %%
clf = evopipe.EvoPipeClassifier(preproc_l, classif_l, 2, pop_size=50, ngen=30)
clf.fit(train_X, train_Y)

score = clf.score(test_X, test_Y)
print("\nBest pipeline test score: {}\n".format(score))

best_pipes = clf.best_pipelines()

for pipe in best_pipes:
    pipe.fit(train_X, train_Y)
    score = pipe.score(test_X, test_Y)
    
    pipe_named_steps = []
    for key, val in pipe.steps:
        pipe_named_steps.append(key)       
    print("Score: {}, Pipe: {}".format(score, pipe_named_steps))
# Out:
# Gen 1:
#
# Hall of fame:
# ['minmaxscaler', 'pca', 'linearsvc']
# ['minmaxscaler', 'kernelpca', 'linearsvc']
# ['standardscaler', 'minmaxscaler', 'quadraticdiscriminantanalysis']
# ['standardscaler-1', 'standardscaler-2', 'kneighborsclassifier']
# ['minmaxscaler', 'standardscaler', 'kneighborsclassifier']
#
# Gen 6:
#
# Hall of fame:
# ['selectkbest', 'minmaxscaler', 'quadraticdiscriminantanalysis']
# ['selectkbest', 'standardscaler', 'quadraticdiscriminantanalysis']
# ['minmaxscaler', 'kernelpca', 'kneighborsclassifier']
# ['standardscaler', 'minmaxscaler', 'linearsvc']
# ['minmaxscaler', 'pca', 'linearsvc']
#
# Gen 11:
#
# Hall of fame:
# ['selectkbest', 'pca', 'quadraticdiscriminantanalysis']
# ['selectkbest', 'minmaxscaler', 'quadraticdiscriminantanalysis']
# ['selectkbest', 'standardscaler', 'quadraticdiscriminantanalysis']
# ['minmaxscaler', 'kernelpca', 'kneighborsclassifier']
# ['standardscaler', 'minmaxscaler', 'linearsvc']
#
# Gen 16:
#
# Hall of fame:
# ['selectkbest', 'pca', 'quadraticdiscriminantanalysis']
# ['selectkbest', 'minmaxscaler', 'quadraticdiscriminantanalysis']
# ['selectkbest', 'standardscaler', 'quadraticdiscriminantanalysis']
# ['minmaxscaler', 'kernelpca', 'kneighborsclassifier']
# ['standardscaler', 'minmaxscaler', 'linearsvc']
#
# Gen 21:
#
# Hall of fame:
# ['selectkbest', 'quadraticdiscriminantanalysis']
# ['selectkbest', 'pca', 'quadraticdiscriminantanalysis']
# ['selectkbest', 'minmaxscaler', 'quadraticdiscriminantanalysis']
# ['selectkbest', 'standardscaler', 'quadraticdiscriminantanalysis']
# ['minmaxscaler', 'kernelpca', 'kneighborsclassifier']
#
# Gen 26:
#
# Hall of fame:
# ['selectkbest', 'quadraticdiscriminantanalysis']
# ['selectkbest', 'pca', 'quadraticdiscriminantanalysis']
# ['selectkbest', 'minmaxscaler', 'quadraticdiscriminantanalysis']
# ['selectkbest', 'standardscaler', 'quadraticdiscriminantanalysis']
# ['minmaxscaler', 'kernelpca', 'kneighborsclassifier']
#
# Best pipeline score: 1.0
#
# Score: 1.0, Pipe: ['selectkbest', 'quadraticdiscriminantanalysis']
# Score: 1.0, Pipe: ['selectkbest', 'pca', 'quadraticdiscriminantanalysis']
# Score: 1.0, Pipe: ['selectkbest', 'minmaxscaler', 'quadraticdiscriminantanalysis']
# Score: 1.0, Pipe: ['selectkbest', 'standardscaler', 'quadraticdiscriminantanalysis']
# Score: 0.9777777777777777, Pipe: ['minmaxscaler', 'kernelpca', 'kneighborsclassifier']

# %%
print(clf.logbook)

gen = clf.logbook.select("gen")
avgs, mins, maxs, vars = clf.logbook.select("avg", "min", "max", "var")

sns.set()

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(gen, avgs, label='Average')
ax1.set_xlabel("Generation")
ax1.set_ylabel("Fitness")

ax1.plot(gen, maxs, label='Maximum')
ax1.set_xlabel("Generation")
# ax1.set_ylabel("Maximum Fitness")

plt.show()
# Out:
# avg     	gen	max     	min     	var
# 0.834654	0  	0.97018 	0       	0.0454319
# 0.932357	1  	0.977426	0.376007	0.0094822
# 0.939286	2  	0.977426	0.277806	0.0182696
# 0.937444	3  	0.977426	0       	0.0273684
# 0.943434	4  	0.977426	0.325788	0.0150269
# 0.941381	5  	0.977426	0       	0.0276689
# 0.964343	6  	0.977426	0.323283	0.00838689
# 0.977426	7  	0.977426	0.977426	0
# 0.976206	8  	0.977426	0.9397  	3.05825e-05
# 0.952307	9  	0.977426	0.323283	0.0102384
# 0.97313 	10 	0.977426	0.762616	0.000904408
# 0.965087	11 	0.977426	0.36048 	0.00746019
# 0.952937	12 	0.977426	0.323283	0.0124216
# 0.963298	13 	0.977426	0.36048 	0.0075729
# 0.975333	14 	0.977426	0.880542	0.000184552
# 0.951556	15 	0.977426	0.323283	0.0155067
# 0.975624	16 	0.977426	0.895234	0.000133113
# 0.968476	17 	0.977426	0.552364	0.00353896
# 0.976382	18 	0.977426	0.925208	5.34444e-05
# 0.95973 	19 	0.977426	0.257078	0.010317
# 0.977113	20 	0.977426	0.969521	2.35362e-06
# 0.963463	21 	0.977426	0.376007	0.00722618
# 0.95882 	22 	0.977426	0.323283	0.0086656
# 0.977426	23 	0.977426	0.977426	0
# 0.970287	24 	0.977426	0.620484	0.00249718
# 0.935529	25 	0.977426	0.257078	0.0275588
# 0.977271	26 	0.977426	0.969674	1.17781e-06
# 0.974737	27 	0.977426	0.866225	0.000243685
# 0.977116	28 	0.977426	0.969674	2.30755e-06
# 0.968274	29 	0.977426	0.603196	0.00277539
